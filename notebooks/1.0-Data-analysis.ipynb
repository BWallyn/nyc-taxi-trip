# %% [markdown]
# # Analyze data
# # 1. Imports
# ## 1.1 Packages

# %%
import os
import pandas as pd
import sys

# %%
sys.path.append('../src/visualization')
from visualize import plot_distribution_feat_cat, plot_distribution_feat_cont

# %% [markdown]
# ## 1.2 Options

# %%
path = '../data/interim'

# %%
pd.set_option("display.max_columns", 500)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 1.3 Dataset

# %%
df = pd.read_parquet(os.path.join(path, "yellow_trip_2023-1_2023-5_duration.parquet"))

# %% [markdown]
# # 2. Analyze
# ## 2.1 Overall analysis

# %%
feat_cat = [
    "VendorID", "RatecodeID", "store_and_fwd_flag", "PULocationID", "DOLocationID", "payment_type", "improvement_surcharge"
]

feat_cont = [
    "passenger_count",
    # "trip_distance",
    "fare_amount", "extra", "mta_tax", "tip_amount", "tolls_amount", "total_amount", "congestion_surcharge", "Airport_fee",
]
feat_date = ["tpep_pickup_datetime", "tpep_dropoff_datetime"]

target = "duration"

# %%
df.sample(5)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2503259         2  2023-03-24 12:37:56   2023-03-24 12:48:54              1.0
# 2515405         2  2023-04-24 20:58:41   2023-04-24 21:03:35              1.0
# 2164761         2  2023-04-21 15:51:38   2023-04-21 15:57:09              1.0
# 455797          2  2023-05-05 03:01:12   2023-05-05 03:29:36              2.0
# 169551          2  2023-02-02 17:20:35   2023-02-02 17:26:30              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 2503259           1.22         1.0                  N           261
# 2515405           1.47         1.0                  N           237
# 2164761           1.21         1.0                  N           141
# 455797           24.98         5.0                  N           133
# 169551            0.67         1.0                  N           237
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
print('Shape of the dataset:', df.shape)
# Out:
# Shape of the dataset: (16186386, 21)

# %%
(df.isna().sum() / df.shape[0]).reset_index(drop=False).style.bar()
# Out:
# <style type="text/css">
# #T_700e7_row0_col1, #T_700e7_row1_col1, #T_700e7_row2_col1, #T_700e7_row4_col1, #T_700e7_row7_col1, #T_700e7_row8_col1, #T_700e7_row9_col1, #T_700e7_row10_col1, #T_700e7_row11_col1, #T_700e7_row12_col1, #T_700e7_row13_col1, #T_700e7_row14_col1, #T_700e7_row15_col1, #T_700e7_row16_col1, #T_700e7_row20_col1 {
#   width: 10em;
# }
# #T_700e7_row3_col1, #T_700e7_row5_col1, #T_700e7_row6_col1, #T_700e7_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.2%, transparent 3.2%);
# }
# #T_700e7_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_700e7_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.0%, transparent 26.0%);
# }
# </style>
# <table id="T_700e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_700e7_level0_col0" class="col_heading level0 col0" >index</th>
# ...

# %% [markdown]
# ## 2.2 Analyze features

# %%
plot_distribution_feat_cat(df, feat_cat)

# %%
plot_distribution_feat_cat(df, feat_cont)
